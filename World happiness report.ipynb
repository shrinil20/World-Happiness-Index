# %%
#importing necesary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#performing some basic operations on my selected dataset.

# %%
data = pd.read_csv("dataset.csv")
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# ###gave us the output of the first five rows

# %%
data.tail()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# ...

# %% [markdown]
# ###gave us the output of last five cells

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %% [markdown]
# ###information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
data.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %% [markdown]
# ###describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the
# ###Series or DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %%
data.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %% [markdown]
# ###isnull() function detect missing values in the given series object. It return a boolean same-sized object indicating if the
# ###values are NA.

# %%
data["Country name"].unique()
# Out:
# array(['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands',
#        'Norway', 'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
#        'Australia', 'Israel', 'Germany', 'Canada', 'Ireland',
#        'Costa Rica', 'United Kingdom', 'Czech Republic', 'United States',
#        'Belgium', 'France', 'Bahrain', 'Malta',
#        'Taiwan Province of China', 'United Arab Emirates', 'Saudi Arabia',
#        'Spain', 'Italy', 'Slovenia', 'Guatemala', 'Uruguay', 'Singapore',
#        'Kosovo', 'Slovakia', 'Brazil', 'Mexico', 'Jamaica', 'Lithuania',
#        'Cyprus', 'Estonia', 'Panama', 'Uzbekistan', 'Chile', 'Poland',
#        'Kazakhstan', 'Romania', 'Kuwait', 'Serbia', 'El Salvador',
#        'Mauritius', 'Latvia', 'Colombia', 'Hungary', 'Thailand',
#        'Nicaragua', 'Japan', 'Argentina', 'Portugal', 'Honduras',
#        'Croatia', 'Philippines', 'South Korea', 'Peru',
#        'Bosnia and Herzegovina', 'Moldova', 'Ecuador', 'Kyrgyzstan',
# ...

# %% [markdown]
# ###The unique() function is used to find the unique elements of an array. Returns the sorted unique elements of an array.

# %%
result_country = data["Healthy life expectancy"]
result_country
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %% [markdown]
# ###here we created a variable named result_country and stored the value of column named healthy life expectancy in it and printed it.

# %%
country = data["Country name"]
country
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %% [markdown]
# ###here we created a variable named country and stored the value of column named  Country name in it and printed it.

# %%
#imported matplotlib library for plotting different types of graphs.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Show healthy life expectancy in 2021 all over the world.

# %%
plt.figure(figsize=(25,10))
plt.bar(country, result_country)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ###here we plotted a bar graph of different countries for the healthy life expectancy and it seems that singapore and
# ###hong kong has high expectancy of a healthy life.

# %%
data.groupby("Healthy life expectancy").count()
# Out:
#                          Country name  Regional indicator  Ladder score  \
# Healthy life expectancy
# 48.478                              1                   1             1
# 48.700                              1                   1             1
# 50.102                              1                   1             1
# 50.114                              1                   1             1
# 50.833                              1                   1             1
# ...                               ...                 ...           ...
# 74.400                              1                   1             1
# 74.700                              1                   1             1
# 75.100                              1                   1             1
# 76.820                              1                   1             1
# 76.953                              1                   1             1
#
#                          Standard error of ladder score  upperwhisker  \
# ...

# %% [markdown]
# ###I grouped the data by the column named healthy life expectancy and applied count function which will return the values for the
# ###column passed and for other colimns it will return the number of values the cell has.

# %%
data["Healthy life expectancy"].max()
# Out:
# 76.953

# %% [markdown]
# ###It will return the max value of the column passed.

# %%
dataframe = data.nlargest(10, ["Healthy life expectancy"])
dataframe
# Out:
#                  Country name     Regional indicator  Ladder score  \
# 31                  Singapore         Southeast Asia         6.377
# 76  Hong Kong S.A.R. of China              East Asia         5.477
# 55                      Japan              East Asia         5.940
# 26                      Spain         Western Europe         6.491
# 2                 Switzerland         Western Europe         7.571
# 20                     France         Western Europe         6.690
# 10                  Australia  North America and ANZ         7.183
# 61                South Korea              East Asia         5.845
# 38                     Cyprus         Western Europe         6.223
# 73               North Cyprus         Western Europe         5.536
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 31                           0.043         6.460         6.293
# 76                           0.049         5.573         5.380
# ...

# %% [markdown]
# ###It will return the top 10 values of the column passed which is healthy life expectancy.

# %%
temp = data.nlargest(5, ["Healthy life expectancy"])
temp["Healthy life expectancy"]
# Out:
# 31    76.953
# 76    76.820
# 55    75.100
# 26    74.700
# 2     74.400
# Name: Healthy life expectancy, dtype: float64

# %%
resultHLE = temp["Healthy life expectancy"]
resultHLE
# Out:
# 31    76.953
# 76    76.820
# 55    75.100
# 26    74.700
# 2     74.400
# Name: Healthy life expectancy, dtype: float64

# %% [markdown]
# # Check whether Switzerland, France, Australia are present in dataset.

# %%
data[data['Country name'].isin(['Switzerland', 'France', 'Australia'])]
# Out:
#    Country name     Regional indicator  Ladder score  \
# 2   Switzerland         Western Europe         7.571
# 10    Australia  North America and ANZ         7.183
# 20       France         Western Europe         6.690
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 2                            0.036         7.643         7.500
# 10                           0.041         7.265         7.102
# 20                           0.037         6.762         6.618
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 2                  11.117           0.942                     74.4
# 10                 10.796           0.940                     73.9
# 20                 10.704           0.942                     74.0
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 2                          0.919       0.025                      0.292
# 10                         0.914       0.159                      0.442
# ...

# %% [markdown]
# ###It returned all the details of the 3 rows which were requeated.

# %% [markdown]
# # Group data by country name and return generosity of each country.

# %%
data.groupby("Country name").Generosity.sum()
# Out:
# Country name
# Afghanistan   -0.102
# Albania       -0.030
# Algeria       -0.067
# Argentina     -0.182
# Armenia       -0.168
#                ...
# Venezuela     -0.169
# Vietnam       -0.098
# Yemen         -0.147
# Zambia         0.061
# Zimbabwe      -0.047
# Name: Generosity, Length: 149, dtype: float64

# %% [markdown]
# ###It returned country names along with generosity in ascending order.

# %% [markdown]
# # Group data by country name with healthy life expectancy, freedom to make life choices, generosity and social support

# %%
data.groupby("Country name")['Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Social support'].sum()
# Out:
# <ipython-input-36-bd0b4f331d41>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Country name")['Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Social support'].sum()
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Afghanistan                    52.493                         0.382
# Albania                        68.999                         0.785
# Algeria                        66.005                         0.480
# Argentina                      69.000                         0.828
# Armenia                        67.055                         0.825
# ...                               ...                           ...
# Venezuela                      66.700                         0.615
# Vietnam                        68.034                         0.940
# ...

# %% [markdown]
# ###It returned data of 4 requested columns for all the countries in ascending order.

# %%
data1 = pd.read_csv("dataset1.csv")
data1.head()
# Out:
#   Country name  year  Life Ladder   GDP   Social support  \
# 0  Afghanistan  2008        3.724  7.370           0.451
# 1  Afghanistan  2009        4.402  7.540           0.552
# 2  Afghanistan  2010        4.758  7.647           0.539
# 3  Afghanistan  2011        3.832  7.620           0.521
# 4  Afghanistan  2012        3.783  7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258
# ...

# %%
data1['year'].min()
# Out:
# 2005

# %% [markdown]
# ###It returned minimun year.

# %%
data1['year'].max()
# Out:
# 2020

# %% [markdown]
# ###It returned maximum year

# %%
result = data1.loc[data1['Country name'] == 'India']['year']
result
# Out:
# 732    2006
# 733    2007
# 734    2008
# 735    2009
# 736    2010
# 737    2011
# 738    2012
# 739    2013
# 740    2014
# 741    2015
# 742    2016
# 743    2017
# 744    2018
# 745    2019
# 746    2020
# Name: year, dtype: int64

# %% [markdown]
# ###We created a variable named result through which we returned all the year given for INDIA.

# %%
result1 = data1.loc[data1['Country name'] == 'India']['Social support']
result1
# Out:
# 732    0.707
# 733    0.569
# 734    0.684
# 735    0.653
# 736    0.605
# 737    0.553
# 738    0.511
# 739    0.553
# 740    0.621
# 741    0.610
# 742    0.614
# 743    0.607
# 744    0.638
# 745    0.561
# 746    0.617
# Name: Social support, dtype: float64

# %% [markdown]
# ###We created a variable named result1 through which we returned Social Support given for INDIA.

# %% [markdown]
# # Display the data of Social support vs YEAR for INDIA

# %%
plt.plot(result, result1)

# %% [markdown]
# ###We made a line graph for Social support vs YEAR for INDIA to graphically represent the data.

# %% [markdown]
# # Display all the column names available.

# %%
data1.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'GDP ', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect'],
#       dtype='object')

# %% [markdown]
# # Get the data for all the countries whose Generosity is less than 0

# %%
res = data1.loc[data1['Generosity'] <= -0.1]
res
# Out:
#      Country name  year  Life Ladder   GDP   Social support  \
# 9     Afghanistan  2017        2.662  7.697           0.491
# 11    Afghanistan  2019        2.375  7.697           0.420
# 13        Albania  2009        5.485  9.262           0.833
# 14        Albania  2010        5.269  9.303           0.733
# 15        Albania  2011        5.867  9.331           0.759
# ...           ...   ...          ...    ...             ...
# 1917        Yemen  2017        3.254  7.578           0.790
# 1926       Zambia  2013        5.244  8.131           0.761
# 1940     Zimbabwe  2012        4.955  7.983           0.896
# 1941     Zimbabwe  2013        4.690  7.985           0.799
# 1943     Zimbabwe  2015        3.703  7.992           0.736
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 9                                52.80                         0.427
# 11                               52.40                         0.394
# ...

# %% [markdown]
# ###It returned all the data for all the countries whose Generosity is less than -0.1.

# %% [markdown]
# # Fetch the country data whose Generosity is less than -0.1 in the year 2009

# %%
res1 = data1.loc[(data1['year']==2009) & (data1['Generosity']< -0.1)]
res1
# Out:
#       Country name  year  Life Ladder    GDP   Social support  \
# 13         Albania  2009        5.485   9.262           0.833
# 40       Argentina  2009        6.424   9.977           0.919
# 55         Armenia  2009        4.178   9.111           0.680
# 136        Belarus  2009        5.564   9.681           0.908
# 345          China  2009        4.454   8.996           0.798
# 411        Croatia  2009        5.433  10.104           0.861
# 486        Ecuador  2009        6.022   9.225           0.779
# 516    El Salvador  2009        6.839   8.883           0.734
# 531        Estonia  2009        5.138  10.144           0.874
# 594        Georgia  2009        3.801   9.116           0.544
# 638         Greece  2009        6.039  10.491           0.793
# 712        Hungary  2009        4.895  10.097           0.901
# 775           Iraq  2009        4.775   9.076           0.862
# 830    Ivory Coast  2009        4.197   8.209           0.667
# ...

# %% [markdown]
# ###We got the data for all the countries whose Generosity is less than -0.1 in the specific year 2009.
# ###We can tell from the above data that all these countries whose generosity is less than -0.1 have lost generosity :(

# %% [markdown]
# # country data whose freedom was greater than 0.90 year 2011

# %%
cou = data1.loc[(data1['year']==2011) & (data1['Freedom to make life choices']> 0.90)]
cou
# Out:
#      Country name  year  Life Ladder    GDP   Social support  \
# 70      Australia  2011        7.406  10.733           0.967
# 83        Austria  2011        7.471  10.887           0.944
# 268      Cambodia  2011        4.161   7.960           0.716
# 298        Canada  2011        7.426  10.738           0.922
# 401    Costa Rica  2011        7.229   9.705           0.892
# 454       Denmark  2011        7.788  10.848           0.962
# 554       Finland  2011        7.354  10.754           0.938
# 569        France  2011        6.959  10.671           0.921
# 611       Germany  2011        6.621  10.813           0.947
# 790       Ireland  2011        7.007  10.878           0.977
# 1018   Luxembourg  2011        7.101  11.595           0.934
# 1215  Netherlands  2011        7.564  10.875           0.938
# 1229  New Zealand  2011        7.191  10.536           0.954
# 1310         Oman  2011        6.853  10.382             NaN
# ...

# %% [markdown]
# ###We got all the data of all the countries whose freedom to make life choices was greater than 0.90 in the specific year 2011

# %%
country1 = data1.loc[(data1['Freedom to make life choices']>=0.90)]
country1
# Out:
#      Country name  year  Life Ladder    GDP   Social support  \
# 66      Australia  2005        7.341  10.659           0.968
# 68      Australia  2008        7.254  10.719           0.947
# 69      Australia  2010        7.450  10.722           0.955
# 70      Australia  2011        7.406  10.733           0.967
# 71      Australia  2012        7.196  10.754           0.945
# ...           ...   ...          ...     ...             ...
# 1878   Uzbekistan  2019        6.154   8.853           0.915
# 1895      Vietnam  2007        5.422   8.394           0.856
# 1901      Vietnam  2013        5.023   8.668           0.759
# 1906      Vietnam  2018        5.296   8.934           0.832
# 1907      Vietnam  2019        5.467   8.992           0.848
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 66                               71.40                         0.935
# 68                               71.88                         0.916
# ...

# %% [markdown]
# ###We got all the data of all the countries whose freedom to make life choices was greater than 0.90.

# %% [markdown]
# # What is the highest perception of corruption

# %%
sns.countplot(x=data1['Perceptions of corruption'])
# Out:
# <AxesSubplot:xlabel='Perceptions of corruption', ylabel='count'>

# %% [markdown]
# ###From this we can conclude that at some point corruption was highest that is in 14 countries.

# %% [markdown]
# # What is positive & negative affect in 2014 in India?

# %%
cou1 = data1.loc[(data1['Country name']== 'India') & (data1['year'] == 2014)]['Positive affect']
cou1
# Out:
# 740    0.711
# Name: Positive affect, dtype: float64

# %% [markdown]
# ###I fetched the data of positive affect of INDIA in year 2014

# %%
cou2 = data1.loc[(data1['Country name']== 'India') & (data1['year'] == 2014)]['Negative affect']
cou2
# Out:
# 740    0.285
# Name: Negative affect, dtype: float64

# %% [markdown]
# ###I fetched the data of negative affect of INDIA in year 2014

# %%
y = np.array([0.711, 0.285])
mylabels = ["Positive affect", "Negative affect"]
myexplode = [0.2, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
# Out:
# <ipython-input-55-471dd5f03264>:4: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(y, labels = mylabels, explode = myexplode)

# %% [markdown]
# ###I plotted the positive and negative affect of INDIA in year 2014 in the form of pie chart.
